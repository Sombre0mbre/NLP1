# %% [markdown]
# #**Introduction to Natural Language Processing 2 Lab03**

# %% [markdown]
# ##**Create a searchable index**

# %%
# !pip install beir
# !pip install -U sentence-transformers

import random
import time
import torch
import faiss
import numpy as np
from beir import util, LoggingHandler
import logging
import pathlib, os
from beir.datasets.data_loader import GenericDataLoader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting beir
#   Downloading beir-1.0.1.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 3.4 MB/s
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 4.9 MB/s
# Collecting pytrec_eval
#   Downloading pytrec_eval-0.5.tar.gz (15 kB)
# Collecting faiss_cpu
#   Downloading faiss_cpu-1.7.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      |████████████████████████████████| 17.0 MB 26.8 MB/s
# Collecting elasticsearch==7.9.1
#   Downloading elasticsearch-7.9.1-py2.py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 57.9 MB/s
# Collecting datasets
#   Downloading datasets-2.7.0-py3-none-any.whl (451 kB)
#      |████████████████████████████████| 451 kB 51.7 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch==7.9.1->beir) (2022.9.24)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch==7.9.1->beir) (1.24.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (1.21.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (1.3.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (6.0)
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 63.7 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (2022.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (4.13.0)
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 67.2 MB/s
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (0.3.6)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 68.6 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets->beir) (3.8.3)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (4.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (1.3.3)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->beir) (0.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets->beir) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets->beir) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->beir) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->beir) (3.0.4)
# Collecting urllib3>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 69.2 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets->beir) (3.10.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets->beir) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets->beir) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets->beir) (1.15.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 46.8 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->beir) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->beir) (0.13.1+cu113)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->beir) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->beir) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->beir) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 58.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->beir) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 54.6 MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers->beir) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers->beir) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers->beir) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers->beir) (7.1.2)
# Building wheels for collected packages: beir, pytrec-eval, sentence-transformers
#   Building wheel for beir (setup.py) ... done
#   Created wheel for beir: filename=beir-1.0.1-py3-none-any.whl size=62516 sha256=f024ea18441b08e8b0607fbd83b054c8ba0434eb91c785a695399ec56c17ebbc
#   Stored in directory: /root/.cache/pip/wheels/49/e8/58/18d0218f6a1eb9b343b100181915dccc668d7fe688704be89c
#   Building wheel for pytrec-eval (setup.py) ... done
#   Created wheel for pytrec-eval: filename=pytrec_eval-0.5-cp37-cp37m-linux_x86_64.whl size=268418 sha256=408a25f9beef7f73d79e16e634eb7df7d7511b06606f52104fabd04354b926e6
#   Stored in directory: /root/.cache/pip/wheels/42/96/77/0829b8b2606f90f61ba10a51277629d2b615604e122ee932f4
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=5e80e818756592c5a67200ede0b4b4802066cdf7de5652427d67719311346156
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built beir pytrec-eval sentence-transformers
# Installing collected packages: urllib3, tokenizers, huggingface-hub, xxhash, transformers, sentencepiece, responses, multiprocess, sentence-transformers, pytrec-eval, faiss-cpu, elasticsearch, datasets, beir
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed beir-1.0.1 datasets-2.7.0 elasticsearch-7.9.1 faiss-cpu-1.7.3 huggingface-hub-0.11.0 multiprocess-0.70.14 pytrec-eval-0.5 responses-0.18.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.24.0 urllib3-1.25.11 xxhash-3.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.7/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.24.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.13.1+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.11.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.1.97)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.12.1+cu113)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)

# %% [markdown]
# We download the dataset with Beir library

# %%
# Just some code to print debug information to stdout
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[LoggingHandler()])

# Getting our dpedia dataset
dataset = "dbpedia-entity"
url = "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{}.zip".format(dataset)
out_dir = os.path.join(os.getcwd(), "datasets")
data_path = util.download_and_unzip(url, out_dir)
print("Dataset downloaded here: {}".format(data_path))
data_path = "datasets/dbpedia-entity"
corpus, queries, qrels = GenericDataLoader(data_path).load(split="test")
# Out:
# /content/datasets/dbpedia-entity.zip:   0%|          | 0.00/610M [00:00<?, ?iB/s]
# Dataset downloaded here: /content/datasets/dbpedia-entity
#   0%|          | 0/4635922 [00:00<?, ?it/s]

# %%
print((len(corpus),type(corpus)))
print((len(queries),type(queries)))
print((len(qrels),type(qrels)))
# Out:
# (114877, <class 'dict'>)
# (400, <class 'dict'>)
# (400, <class 'dict'>)

# %% [markdown]
# 1. Data is divided in three parts :
#
#
# *   corpus is a dictionary with three fields _id with unique document identifier, title with document title (optional) and text with document paragraph or passage. Each text for the corpus are answers to questions.
# *   queries is a dictionary with two fields _id with unique query identifier and text with query text. Each query is a question.
# *   qrels is  a  dictionary , i.e. the query-id. The value of this dictionnary is also one. The second dictionary have information about corpus-id and score in this order. It links a question to an answer.

# %% [markdown]
# 2. To ease the problem, extract all the document from the corpus which are relevant to at least one query. Then, add 100K random documents which are not relevant to any query.
#
# To do this part we made 3 function:
# - The first one to get all valid_id
# - The second one to get 100k non valid id
# - The last one to merge our new dataset

# %%
def good_id(data):
  """ 
    Take qrels dictionary and return a set containing all id that are present 
    in at least 1 query  

    Parameters
    ----------
    data : <class 'dict'>

    Returns
    -------
    res : <class 'set'>
  
  """
  res = set()
  for values in data.values():
    res.update({k: v for k,v in values.items() if v != 0})
  return res

data_searched = good_id(qrels)
print("Nb of valid id: ",len(data_searched))

def no_result_id(data):
  """ 
    Take 100k random data from the corpus that have no quey search

    Parameters
    ----------
    data : <class 'set'>

    Returns
    -------
    outputs : <class 'set'>
  
  """
  res = set(corpus.keys()) - data
  return set(random.sample(list(res),100000))

data_not_searched = no_result_id(data_searched)
print("100k data with no valid id: "+ str(len(data_not_searched))) #Sum of non valid id

def get_data(data, keys):
  """ 
    Take a union dataset from our previous function and return 
    our new corpus

    Parameters
    ----------
    data : <class 'dict'>
    keys : <class 'set'>

    Returns
    -------
    res_corpus : <class 'dict'>
  
  """
  res_corpus = corpus
  delete = set(corpus) - keys
  for keys in delete:
    del res_corpus[keys]
  return res_corpus

dataset = data_searched.union(data_not_searched)
data = get_data(corpus,dataset)
print(len(data)) #Sum of our new dataset
# Out:
# Nb of valid id:  14877
# 100k data with no valid id: 100000
# 114877

# %% [markdown]
# 3. Embed the reduced corpus and the queries using the chosen model

# %% [markdown]
# For this part we will test 4 different model, and take our best model to test the ANN version

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('msmarco-distilroberta-base-v2')
model_mini_v3_12 = SentenceTransformer('msmarco-MiniLM-L-12-v3')
model_mini_v3_6 = SentenceTransformer('msmarco-MiniLM-L-6-v3')
model_roberta_v3 = SentenceTransformer('msmarco-roberta-base-v3')
L_model = [model,model_mini_v3_12,model_mini_v3_6,model_roberta_v3]
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/683 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/736 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/432 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/736 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.68k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/627 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/430 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.70k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/678 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %% [markdown]
# This next part take 25 Minutes with GPU in collabs because some models are really heavy

# %%
corpus_value = [text["text"] for text in data.values()]

def load_model(model_list):
  """ 
    Load every model froom our list

    Parameters
    ----------
    model_list: <class 'list'>

    Returns
    -------
    res : <class 'list'>
  
  """
  res= []
  for model in model_list:
    corpus_embeddings = model.encode(corpus_value, convert_to_tensor=True)
    print("1 done")
    res.append(corpus_embeddings)
  return res

print(type(L_model))
List_model = load_model(L_model)
print(type(List_model))
queries_val = queries.values()
# Out:
# <class 'list'>
# 1 done
# 1 done
# 1 done
# 1 done
# <class 'list'>

# %%
List_of_scores = []
List_of_times = [] 

def Map_time(model,corpus_emb,corpus_val,queries_val,mini):
  """ 
    Compute The MAP and time for every query
    
    Parameters
    ----------
    model: <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
    corpus_emb: <class 'torch.Tensor'>
    corpus_val: <class 'list'>
    queries_val: <class 'dict_values'>
    mini: int  

  """
  top_k = min(mini,len(corpus_val))
  for query in queries_val:
    score = []
    ti = []
    start_time = time.time()
    query_emb= model.encode(query, convert_to_tensor=True)

    cos_scores = util.cos_sim(query_emb, corpus_emb)[0]
    top_results = torch.topk(cos_scores, k=top_k)
    result = top_results[0].tolist()
    List_of_scores.append(result)
    end_time = time.time()
    ti = end_time-start_time
    List_of_times.append(ti)

for model,corp_emb in zip(L_model,List_model):
  Map_time(model,corp_emb,corpus_value,queries_val,100)

# %%
def print_result(queries_val):
  """ 
    Print our result for the differents models

    Parameters
    ----------
    queries_val: dict_values
  
  """
  cont = 0
  for query in queries_val:
    print("\n\n-------------------------------------------\n\n")
    print("Query: ",query)
    print("\n Score Model distilberta: ",sum(List_of_scores[cont])/100)
    print("Time Model distilberta: ",List_of_times[cont])
    print("\n Score Model mini_v3_12: ",sum(List_of_scores[400+cont])/100)
    print("Time Model distilberta: ",List_of_times[400+cont])
    print("\n Score Model mini_v3_6: ",sum(List_of_scores[800+cont])/100)
    print("Time Model distilberta: ",List_of_times  [800+cont])
    print("\n Score Model roberta v3: ",sum(List_of_scores[1200+cont])/100)
    print("Time Model distilberta: ",List_of_times[1200+cont])
    cont = cont + 1
print_result(queries_val)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#
# Query:  circus mammals
#
#  Score Model distilberta:  0.462085117995739
# Time Model distilberta:  0.0138092041015625
#
#  Score Model mini_v3_12:  0.34524727463722227
# Time Model distilberta:  0.017473697662353516
#
#  Score Model mini_v3_6:  0.3582668137550354
# Time Model distilberta:  0.009717702865600586
#
#  Score Model roberta v3:  0.2913888895511627
# Time Model distilberta:  0.01878952980041504
#
#
# -------------------------------------------
#
#
# Query:  Works by Charles Rennie Mackintosh
#
#  Score Model distilberta:  0.44340875923633577
# Time Model distilberta:  0.01418924331665039
#
#  Score Model mini_v3_12:  0.4206217816472054
# Time Model distilberta:  0.022380590438842773
#
#  Score Model mini_v3_6:  0.41722067564725873
# Time Model distilberta:  0.010225534439086914
#
#  Score Model roberta v3:  0.36951981782913207
# Time Model distilberta:  0.02305746078491211
#
#
# -------------------------------------------
#
#
# Query:  Movies about English hooligans
#
#  Score Model distilberta:  0.3941873115301132
# Time Model distilberta:  0.01930999755859375
#
#  Score Model mini_v3_12:  0.4242052087187767
# Time Model distilberta:  0.01648402214050293
#
#  Score Model mini_v3_6:  0.42491161584854126
# Time Model distilberta:  0.010177850723266602
#
#  Score Model roberta v3:  0.36738902449607846
# Time Model distilberta:  0.019564151763916016
#
#
# -------------------------------------------
#
#
# Query:  List of countries in World War Two
#
#  Score Model distilberta:  0.4079710337519646
# Time Model distilberta:  0.0152740478515625
#
#  Score Model mini_v3_12:  0.4555470377206802
# Time Model distilberta:  0.01585221290588379
#
#  Score Model mini_v3_6:  0.4176648619771004
# Time Model distilberta:  0.009867191314697266
#
#  Score Model roberta v3:  0.36002899169921876
# Time Model distilberta:  0.020194530487060547
#
#
# -------------------------------------------
#
#
# Query:  Axis powers of World War II
#
#  Score Model distilberta:  0.4140592610836029
# Time Model distilberta:  0.015017271041870117
#
#  Score Model mini_v3_12:  0.4304835596680641
# Time Model distilberta:  0.01643061637878418
#
#  Score Model mini_v3_6:  0.4154888692498207
# Time Model distilberta:  0.010170221328735352
#
#  Score Model roberta v3:  0.35326759904623034
# Time Model distilberta:  0.020319223403930664
#
#
# -------------------------------------------
#
#
# Query:  Nordic authors who are known for children's literature
#
#  Score Model distilberta:  0.4755841109156609
# Time Model distilberta:  0.015284299850463867
#
#  Score Model mini_v3_12:  0.48633246183395384
# Time Model distilberta:  0.015536785125732422
#
#  Score Model mini_v3_6:  0.47439570546150206
# Time Model distilberta:  0.010084152221679688
#
#  Score Model roberta v3:  0.42773803412914274
# Time Model distilberta:  0.02053380012512207
#
#
# -------------------------------------------
#
#
# Query:  Paul Auster novels
#
#  Score Model distilberta:  0.49809052497148515
# Time Model distilberta:  0.01937270164489746
#
#  Score Model mini_v3_12:  0.44929356515407565
# Time Model distilberta:  0.015901803970336914
#
#  Score Model mini_v3_6:  0.42794373840093614
# Time Model distilberta:  0.009938240051269531
#
#  Score Model roberta v3:  0.3943881818652153
# Time Model distilberta:  0.0211334228515625
#
#
# -------------------------------------------
#
#
# Query:  Hybrid cars sold in Europe
#
#  Score Model distilberta:  0.440000005364418
# Time Model distilberta:  0.014814615249633789
#
#  Score Model mini_v3_12:  0.4458007836341858
# Time Model distilberta:  0.01565098762512207
#
#  Score Model mini_v3_6:  0.4366132864356041
# Time Model distilberta:  0.009779214859008789
#
#  Score Model roberta v3:  0.34862008899450303
# Time Model distilberta:  0.021019458770751953
#
#
# -------------------------------------------
#
#
# Query:  Tom Hanks movies where he plays a leading role.
#
#  Score Model distilberta:  0.4686903673410416
# Time Model distilberta:  0.01381826400756836
#
#  Score Model mini_v3_12:  0.4122415000200272
# Time Model distilberta:  0.01606583595275879
#
#  Score Model mini_v3_6:  0.41305651009082794
# Time Model distilberta:  0.01004338264465332
#
#  Score Model roberta v3:  0.3151258245110512
# Time Model distilberta:  0.020421504974365234
#
#
# -------------------------------------------
#
#
# Query:  Pure object-oriented programing languages
#
#  Score Model distilberta:  0.41823711335659025
# Time Model distilberta:  0.014384984970092773
#
#  Score Model mini_v3_12:  0.4042572745680809
# Time Model distilberta:  0.016642093658447266
#
#  Score Model mini_v3_6:  0.3998473057150841
# Time Model distilberta:  0.01030874252319336
#
#  Score Model roberta v3:  0.3488732144236565
# Time Model distilberta:  0.020250558853149414
#
#
# -------------------------------------------
#
#
# Query:  Makers of lawn tennis rackets
#
#  Score Model distilberta:  0.3119762107729912
# Time Model distilberta:  0.01388239860534668
#
#  Score Model mini_v3_12:  0.36848149448633194
# Time Model distilberta:  0.017162799835205078
#
#  Score Model mini_v3_6:  0.3708620321750641
# Time Model distilberta:  0.010361909866333008
#
#  Score Model roberta v3:  0.289737851023674
# Time Model distilberta:  0.020595312118530273
#
#
# -------------------------------------------
#
#
# Query:  Computer systems that have a recursive acronym for the name
#
#  Score Model distilberta:  0.36248491317033765
# Time Model distilberta:  0.013942956924438477
#
#  Score Model mini_v3_12:  0.32772558271884916
# Time Model distilberta:  0.016103029251098633
#
#  Score Model mini_v3_6:  0.32857510566711423
# Time Model distilberta:  0.010144710540771484
#
#  Score Model roberta v3:  0.2572982180118561
# Time Model distilberta:  0.020117759704589844
#
#
# -------------------------------------------
#
#
# Query:  Which German cities have more than 250000 inhabitants?
#
#  Score Model distilberta:  0.48778810918331145
# Time Model distilberta:  0.013596534729003906
#
#  Score Model mini_v3_12:  0.45383996903896334
# Time Model distilberta:  0.015860557556152344
#
#  Score Model mini_v3_6:  0.4489329817891121
# Time Model distilberta:  0.010083436965942383
#
#  Score Model roberta v3:  0.42948921710252763
# Time Model distilberta:  0.019824981689453125
#
#
# -------------------------------------------
#
#
# Query:  Who produces Orangina?
#
#  Score Model distilberta:  0.4479843583703041
# Time Model distilberta:  0.014547109603881836
#
#  Score Model mini_v3_12:  0.42501863062381745
# Time Model distilberta:  0.0158236026763916
#
#  Score Model mini_v3_6:  0.3847695118188858
# Time Model distilberta:  0.01018524169921875
#
#  Score Model roberta v3:  0.3734653252363205
# Time Model distilberta:  0.021279573440551758
#
#
# -------------------------------------------
#
#
# Query:  Who is the Formula 1 race driver with the most races?
#
#  Score Model distilberta:  0.4941885569691658
# Time Model distilberta:  0.013808250427246094
#
#  Score Model mini_v3_12:  0.5103438159823418
# Time Model distilberta:  0.02167201042175293
#
#  Score Model mini_v3_6:  0.6063469707965851
# Time Model distilberta:  0.010181427001953125
#
#  Score Model roberta v3:  0.40704293429851535
# Time Model distilberta:  0.019737958908081055
#
#
# -------------------------------------------
#
#
# Query:  Give me all world heritage sites designated within the past five years.
#
#  Score Model distilberta:  0.39250177025794986
# Time Model distilberta:  0.013892412185668945
#
#  Score Model mini_v3_12:  0.4653872349858284
# Time Model distilberta:  0.0175020694732666
#
#  Score Model mini_v3_6:  0.45817054450511935
# Time Model distilberta:  0.01106405258178711
#
#  Score Model roberta v3:  0.317322219312191
# Time Model distilberta:  0.019660472869873047
#
#
# -------------------------------------------
#
#
# Query:  Who is the youngest player in the Premier League?
#
#  Score Model distilberta:  0.4552558055520058
# Time Model distilberta:  0.01459503173828125
#
#  Score Model mini_v3_12:  0.47988911539316176
# Time Model distilberta:  0.015528202056884766
#
#  Score Model mini_v3_6:  0.44659767746925355
# Time Model distilberta:  0.010262489318847656
#
#  Score Model roberta v3:  0.34030377984046933
# Time Model distilberta:  0.0204160213470459
#
#
# -------------------------------------------
#
#
# Query:  Give me all members of Prodigy.
#
#  Score Model distilberta:  0.3393434464931488
# Time Model distilberta:  0.013770341873168945
#
#  Score Model mini_v3_12:  0.3606833231449127
# Time Model distilberta:  0.016058683395385742
#
#  Score Model mini_v3_6:  0.3590383893251419
# Time Model distilberta:  0.010164499282836914
#
#  Score Model roberta v3:  0.29201178669929506
# Time Model distilberta:  0.019516706466674805
#
#
# -------------------------------------------
#
#
# Query:  Give me all cars that are produced in Germany.
#
#  Score Model distilberta:  0.45149493038654326
# Time Model distilberta:  0.013826131820678711
#
#  Score Model mini_v3_12:  0.4248750269412994
# Time Model distilberta:  0.01875019073486328
#
#  Score Model mini_v3_6:  0.4126925304532051
# Time Model distilberta:  0.009786605834960938
#
#  Score Model roberta v3:  0.38750485330820084
# Time Model distilberta:  0.019963741302490234
#
#
# -------------------------------------------
#
#
# Query:  Who was the successor of John F. Kennedy?
#
#  Score Model distilberta:  0.5028072282671928
# Time Model distilberta:  0.01446986198425293
#
#  Score Model mini_v3_12:  0.4549097815155983
# Time Model distilberta:  0.016593217849731445
#
#  Score Model mini_v3_6:  0.45591423869132996
# Time Model distilberta:  0.009902477264404297
#
#  Score Model roberta v3:  0.3625667771697044
# Time Model distilberta:  0.02024221420288086
#
#
# -------------------------------------------
#
#
# Query:  What is the capital of Canada?
#
#  Score Model distilberta:  0.5071957778930664
# Time Model distilberta:  0.014244318008422852
#
#  Score Model mini_v3_12:  0.46312648117542266
# Time Model distilberta:  0.015862226486206055
#
#  Score Model mini_v3_6:  0.45360516220331193
# Time Model distilberta:  0.009699583053588867
#
#  Score Model roberta v3:  0.36739726722240446
# Time Model distilberta:  0.022466421127319336
#
#
# -------------------------------------------
#
#
# Query:  Who is the governor of Texas?
#
#  Score Model distilberta:  0.4865345549583435
# Time Model distilberta:  0.014012575149536133
#
#  Score Model mini_v3_12:  0.5488481020927429
# Time Model distilberta:  0.01638650894165039
#
#  Score Model mini_v3_6:  0.5338598966598511
# Time Model distilberta:  0.009864091873168945
#
#  Score Model roberta v3:  0.4949570432305336
# Time Model distilberta:  0.02242445945739746
#
#
# -------------------------------------------
#
#
# Query:  Who was the father of Queen Elizabeth II?
#
#  Score Model distilberta:  0.5081207656860351
# Time Model distilberta:  0.016365766525268555
#
#  Score Model mini_v3_12:  0.44272688031196594
# Time Model distilberta:  0.016107797622680664
#
#  Score Model mini_v3_6:  0.46902591586112974
# Time Model distilberta:  0.009996175765991211
#
#  Score Model roberta v3:  0.390612867474556
# Time Model distilberta:  0.019922256469726562
#
#
# -------------------------------------------
#
#
# Query:  Which U.S. state has been admitted latest?
#
#  Score Model distilberta:  0.3033149945735931
# Time Model distilberta:  0.014007329940795898
#
#  Score Model mini_v3_12:  0.33307391703128814
# Time Model distilberta:  0.01654052734375
#
#  Score Model mini_v3_6:  0.3428314945101738
# Time Model distilberta:  0.010210514068603516
#
#  Score Model roberta v3:  0.23696832850575447
# Time Model distilberta:  0.021890640258789062
#
#
# -------------------------------------------
#
#
# Query:  Sean Parnell is the governor of which U.S. state?
#
#  Score Model distilberta:  0.46802526742219924
# Time Model distilberta:  0.013849258422851562
#
#  Score Model mini_v3_12:  0.46628738433122635
# Time Model distilberta:  0.017263412475585938
#
#  Score Model mini_v3_6:  0.46714463412761686
# Time Model distilberta:  0.010735273361206055
#
#  Score Model roberta v3:  0.3977735760807991
# Time Model distilberta:  0.019402027130126953
#
#
# -------------------------------------------
#
#
# Query:  Give me all movies directed by Francis Ford Coppola.
#
#  Score Model distilberta:  0.48012147277593614
# Time Model distilberta:  0.013935327529907227
#
#  Score Model mini_v3_12:  0.4111866411566734
# Time Model distilberta:  0.016292810440063477
#
#  Score Model mini_v3_6:  0.45856777906417845
# Time Model distilberta:  0.010020971298217773
#
#  Score Model roberta v3:  0.38625920057296753
# Time Model distilberta:  0.01976633071899414
#
#
# -------------------------------------------
#
#
# Query:  Who is the mayor of Berlin?
#
#  Score Model distilberta:  0.514004445374012
# Time Model distilberta:  0.014222860336303711
#
#  Score Model mini_v3_12:  0.5122193938493729
# Time Model distilberta:  0.016552448272705078
#
#  Score Model mini_v3_6:  0.5053274175524711
# Time Model distilberta:  0.009892940521240234
#
#  Score Model roberta v3:  0.4707608473300934
# Time Model distilberta:  0.019182205200195312
#
#
# -------------------------------------------
#
#
# Query:  Give me all current Methodist national leaders.
#
#  Score Model distilberta:  0.4281594902276993
# Time Model distilberta:  0.01417231559753418
#
#  Score Model mini_v3_12:  0.3655411717295647
# Time Model distilberta:  0.016225337982177734
#
#  Score Model mini_v3_6:  0.3716017645597458
# Time Model distilberta:  0.00987553596496582
#
#  Score Model roberta v3:  0.36153668850660325
# Time Model distilberta:  0.0194852352142334
#
#
# -------------------------------------------
#
#
# Query:  Give me all Australian nonprofit organizations.
#
#  Score Model distilberta:  0.41000129789114
# Time Model distilberta:  0.013811111450195312
#
#  Score Model mini_v3_12:  0.41760633766651156
# Time Model distilberta:  0.015649080276489258
#
#  Score Model mini_v3_6:  0.40686566948890684
# Time Model distilberta:  0.009779214859008789
#
#  Score Model roberta v3:  0.3288246777653694
# Time Model distilberta:  0.019469261169433594
#
#
# -------------------------------------------
#
#
# Query:  Who developed Skype?
#
#  Score Model distilberta:  0.4397844648361206
# Time Model distilberta:  0.014866352081298828
#
#  Score Model mini_v3_12:  0.42069056659936904
# Time Model distilberta:  0.015477657318115234
#
#  Score Model mini_v3_6:  0.4254506227374077
# Time Model distilberta:  0.010576486587524414
#
#  Score Model roberta v3:  0.35404261976480483
# Time Model distilberta:  0.020073890686035156
#
#
# -------------------------------------------
#
#
# Query:  Give me all companies in Munich.
#
#  Score Model distilberta:  0.4309912541508675
# Time Model distilberta:  0.013724088668823242
#
#  Score Model mini_v3_12:  0.3851411956548691
# Time Model distilberta:  0.01617598533630371
#
#  Score Model mini_v3_6:  0.4071496784687042
# Time Model distilberta:  0.009942770004272461
#
#  Score Model roberta v3:  0.34554500967264173
# Time Model distilberta:  0.02056407928466797
#
#
# -------------------------------------------
#
#
# Query:  List all boardgames by GMT.
#
#  Score Model distilberta:  0.34979162365198135
# Time Model distilberta:  0.01514434814453125
#
#  Score Model mini_v3_12:  0.3349528267979622
# Time Model distilberta:  0.015763044357299805
#
#  Score Model mini_v3_6:  0.3733032602071762
# Time Model distilberta:  0.010125398635864258
#
#  Score Model roberta v3:  0.32042465060949327
# Time Model distilberta:  0.01974344253540039
#
#
# -------------------------------------------
#
#
# Query:  Who is the husband of Amanda Palmer?
#
#  Score Model distilberta:  0.4662331482768059
# Time Model distilberta:  0.013725996017456055
#
#  Score Model mini_v3_12:  0.4308207780122757
# Time Model distilberta:  0.019419431686401367
#
#  Score Model mini_v3_6:  0.4295930311083794
# Time Model distilberta:  0.009923934936523438
#
#  Score Model roberta v3:  0.36637892097234726
# Time Model distilberta:  0.019945859909057617
#
#
# -------------------------------------------
#
#
# Query:  Give me all breeds of the German Shepherd dog.
#
#  Score Model distilberta:  0.38666060626506804
# Time Model distilberta:  0.014125347137451172
#
#  Score Model mini_v3_12:  0.3627617734670639
# Time Model distilberta:  0.016053199768066406
#
#  Score Model mini_v3_6:  0.3579380539059639
# Time Model distilberta:  0.010241985321044922
#
#  Score Model roberta v3:  0.32238408356904985
# Time Model distilberta:  0.020377397537231445
#
#
# -------------------------------------------
#
#
# Query:  Which cities does the Weser flow through?
#
#  Score Model distilberta:  0.45056326627731325
# Time Model distilberta:  0.014592170715332031
#
#  Score Model mini_v3_12:  0.38847546368837355
# Time Model distilberta:  0.016168594360351562
#
#  Score Model mini_v3_6:  0.37092823773622513
# Time Model distilberta:  0.009908914566040039
#
#  Score Model roberta v3:  0.4075409743189812
# Time Model distilberta:  0.01964402198791504
#
#
# -------------------------------------------
#
#
# Query:  Which countries are connected by the Rhine?
#
#  Score Model distilberta:  0.4358568811416626
# Time Model distilberta:  0.014304876327514648
#
#  Score Model mini_v3_12:  0.3714068728685379
# Time Model distilberta:  0.015904664993286133
#
#  Score Model mini_v3_6:  0.38636094629764556
# Time Model distilberta:  0.009998559951782227
#
#  Score Model roberta v3:  0.34181594908237456
# Time Model distilberta:  0.019879579544067383
#
#
# -------------------------------------------
#
#
# Query:  Which professional surfers were born on the Philippines?
#
#  Score Model distilberta:  0.45144264966249464
# Time Model distilberta:  0.014119863510131836
#
#  Score Model mini_v3_12:  0.5152202352881432
# Time Model distilberta:  0.016067981719970703
#
#  Score Model mini_v3_6:  0.46501457691192627
# Time Model distilberta:  0.01001429557800293
#
#  Score Model roberta v3:  0.38248629450798033
# Time Model distilberta:  0.019604921340942383
#
#
# -------------------------------------------
#
#
# Query:  In which UK city are the headquarters of the MI6?
#
#  Score Model distilberta:  0.4078293278813362
# Time Model distilberta:  0.014241933822631836
#
#  Score Model mini_v3_12:  0.393966204226017
# Time Model distilberta:  0.01633739471435547
#
#  Score Model mini_v3_6:  0.41399049818515776
# Time Model distilberta:  0.00994420051574707
#
#  Score Model roberta v3:  0.3292098364233971
# Time Model distilberta:  0.019704103469848633
#
#
# -------------------------------------------
#
#
# Query:  Which other weapons did the designer of the Uzi develop?
#
#  Score Model distilberta:  0.44911334723234175
# Time Model distilberta:  0.014039278030395508
#
#  Score Model mini_v3_12:  0.40580350667238235
# Time Model distilberta:  0.016315460205078125
#
#  Score Model mini_v3_6:  0.3901462659239769
# Time Model distilberta:  0.009789705276489258
#
#  Score Model roberta v3:  0.3508665528893471
# Time Model distilberta:  0.019769906997680664
#
#
# -------------------------------------------
#
#
# Query:  What is the second highest mountain on Earth?
#
#  Score Model distilberta:  0.5112437778711318
# Time Model distilberta:  0.013550758361816406
#
#  Score Model mini_v3_12:  0.4404899087548256
# Time Model distilberta:  0.01641368865966797
#
#  Score Model mini_v3_6:  0.4276681700348854
# Time Model distilberta:  0.009933233261108398
#
#  Score Model roberta v3:  0.3751188209652901
# Time Model distilberta:  0.019536495208740234
#
#
# -------------------------------------------
#
#
# Query:  Give me all Frisian islands that belong to the Netherlands.
#
#  Score Model distilberta:  0.43189034432172774
# Time Model distilberta:  0.01402139663696289
#
#  Score Model mini_v3_12:  0.39556642532348635
# Time Model distilberta:  0.016794204711914062
#
#  Score Model mini_v3_6:  0.3981083980202675
# Time Model distilberta:  0.010721683502197266
#
#  Score Model roberta v3:  0.3804335954785347
# Time Model distilberta:  0.020171165466308594
#
#
# -------------------------------------------
#
#
# Query:  What is the ruling party in Lisbon?
#
#  Score Model distilberta:  0.5315060323476791
# Time Model distilberta:  0.013964414596557617
#
#  Score Model mini_v3_12:  0.4303548926115036
# Time Model distilberta:  0.015343904495239258
#
#  Score Model mini_v3_6:  0.46054131150245664
# Time Model distilberta:  0.010092973709106445
#
#  Score Model roberta v3:  0.419428331553936
# Time Model distilberta:  0.020000934600830078
#
#
# -------------------------------------------
#
#
# Query:  Which Greek goddesses dwelt on Mount Olympus?
#
#  Score Model distilberta:  0.49326009035110474
# Time Model distilberta:  0.013491630554199219
#
#  Score Model mini_v3_12:  0.4373288136720657
# Time Model distilberta:  0.01585531234741211
#
#  Score Model mini_v3_6:  0.4445891714096069
# Time Model distilberta:  0.010462045669555664
#
#  Score Model roberta v3:  0.4301711717247963
# Time Model distilberta:  0.0195925235748291
#
#
# -------------------------------------------
#
#
# Query:  Give me the Apollo 14 astronauts.
#
#  Score Model distilberta:  0.4130635195970535
# Time Model distilberta:  0.013944625854492188
#
#  Score Model mini_v3_12:  0.4059169030189514
# Time Model distilberta:  0.01538991928100586
#
#  Score Model mini_v3_6:  0.3948714005947113
# Time Model distilberta:  0.010286092758178711
#
#  Score Model roberta v3:  0.31161383211612703
# Time Model distilberta:  0.01980423927307129
#
#
# -------------------------------------------
#
#
# Query:  What is the time zone of Salt Lake City?
#
#  Score Model distilberta:  0.33989997893571855
# Time Model distilberta:  0.014048337936401367
#
#  Score Model mini_v3_12:  0.3403769013285637
# Time Model distilberta:  0.015542030334472656
#
#  Score Model mini_v3_6:  0.3410367086529732
# Time Model distilberta:  0.010632753372192383
#
#  Score Model roberta v3:  0.2860343742370606
# Time Model distilberta:  0.019680500030517578
#
#
# -------------------------------------------
#
#
# Query:  Which U.S. states are in the same timezone as Utah?
#
#  Score Model distilberta:  0.3022375091910362
# Time Model distilberta:  0.013980865478515625
#
#  Score Model mini_v3_12:  0.3164619866013527
# Time Model distilberta:  0.01711869239807129
#
#  Score Model mini_v3_6:  0.377311532497406
# Time Model distilberta:  0.01193690299987793
#
#  Score Model roberta v3:  0.28095056742429736
# Time Model distilberta:  0.020268678665161133
#
#
# -------------------------------------------
#
#
# Query:  Give me all professional skateboarders from Sweden.
#
#  Score Model distilberta:  0.42382858604192736
# Time Model distilberta:  0.013753414154052734
#
#  Score Model mini_v3_12:  0.4257415056228638
# Time Model distilberta:  0.015064001083374023
#
#  Score Model mini_v3_6:  0.4142132782936096
# Time Model distilberta:  0.010190248489379883
#
#  Score Model roberta v3:  0.3382334116101265
# Time Model distilberta:  0.019494056701660156
#
#
# -------------------------------------------
#
#
# Query:  Give me a list of all lakes in Denmark.
#
#  Score Model distilberta:  0.45790634244680406
# Time Model distilberta:  0.014327049255371094
#
#  Score Model mini_v3_12:  0.4739593371748924
# Time Model distilberta:  0.015166282653808594
#
#  Score Model mini_v3_6:  0.4404502463340759
# Time Model distilberta:  0.010387897491455078
#
#  Score Model roberta v3:  0.3980569577217102
# Time Model distilberta:  0.019793272018432617
#
#
# -------------------------------------------
#
#
# Query:  Give me all Argentine films.
#
#  Score Model distilberta:  0.551419603228569
# Time Model distilberta:  0.02198648452758789
#
#  Score Model mini_v3_12:  0.5668392765522003
# Time Model distilberta:  0.016215801239013672
#
#  Score Model mini_v3_6:  0.5524040594696998
# Time Model distilberta:  0.010820627212524414
#
#  Score Model roberta v3:  0.5476137071847915
# Time Model distilberta:  0.02002739906311035
#
#
# -------------------------------------------
#
#
# Query:  Give me all launch pads operated by NASA.
#
#  Score Model distilberta:  0.37984901130199433
# Time Model distilberta:  0.013979196548461914
#
#  Score Model mini_v3_12:  0.34745878756046294
# Time Model distilberta:  0.017615795135498047
#
#  Score Model mini_v3_6:  0.3668165889382362
# Time Model distilberta:  0.00983572006225586
#
#  Score Model roberta v3:  0.2596808025240898
# Time Model distilberta:  0.019448280334472656
#
#
# -------------------------------------------
#
#
# Query:  Which instruments did John Lennon play?
#
#  Score Model distilberta:  0.5179955261945725
# Time Model distilberta:  0.01339101791381836
#
#  Score Model mini_v3_12:  0.4453635889291763
# Time Model distilberta:  0.01570415496826172
#
#  Score Model mini_v3_6:  0.4293737041950226
# Time Model distilberta:  0.009803056716918945
#
#  Score Model roberta v3:  0.3712700781226158
# Time Model distilberta:  0.019123315811157227
#
#
# -------------------------------------------
#
#
# Query:  Which ships were called after Benjamin Franklin?
#
#  Score Model distilberta:  0.5459946328401566
# Time Model distilberta:  0.014317989349365234
#
#  Score Model mini_v3_12:  0.42074959695339204
# Time Model distilberta:  0.015103340148925781
#
#  Score Model mini_v3_6:  0.4469730228185654
# Time Model distilberta:  0.010093927383422852
#
#  Score Model roberta v3:  0.4160073044896126
# Time Model distilberta:  0.019466638565063477
#
#
# -------------------------------------------
#
#
# Query:  Who are the parents of the wife of Juan Carlos I?
#
#  Score Model distilberta:  0.46269317626953127
# Time Model distilberta:  0.013496160507202148
#
#  Score Model mini_v3_12:  0.46176487594842913
# Time Model distilberta:  0.015464305877685547
#
#  Score Model mini_v3_6:  0.4782941609621048
# Time Model distilberta:  0.0098419189453125
#
#  Score Model roberta v3:  0.38845823764801024
# Time Model distilberta:  0.020189523696899414
#
#
# -------------------------------------------
#
#
# Query:  In which U.S. state is Area 51 located?
#
#  Score Model distilberta:  0.3477477848529816
# Time Model distilberta:  0.013779878616333008
#
#  Score Model mini_v3_12:  0.3979434859752655
# Time Model distilberta:  0.01827383041381836
#
#  Score Model mini_v3_6:  0.3754343968629837
# Time Model distilberta:  0.012682914733886719
#
#  Score Model roberta v3:  0.30487768203020094
# Time Model distilberta:  0.01955723762512207
#
#
# -------------------------------------------
#
#
# Query:  Which daughters of British earls died in the same place they were born in?
#
#  Score Model distilberta:  0.398964968919754
# Time Model distilberta:  0.013854742050170898
#
#  Score Model mini_v3_12:  0.42938071995973587
# Time Model distilberta:  0.017180681228637695
#
#  Score Model mini_v3_6:  0.4102624568343163
# Time Model distilberta:  0.01079559326171875
#
#  Score Model roberta v3:  0.3270273008942604
# Time Model distilberta:  0.02089381217956543
#
#
# -------------------------------------------
#
#
# Query:  List the children of Margaret Thatcher.
#
#  Score Model distilberta:  0.42329536318778993
# Time Model distilberta:  0.016473054885864258
#
#  Score Model mini_v3_12:  0.3594101446866989
# Time Model distilberta:  0.01550436019897461
#
#  Score Model mini_v3_6:  0.37787099748849867
# Time Model distilberta:  0.009764671325683594
#
#  Score Model roberta v3:  0.3356376376748085
# Time Model distilberta:  0.02150869369506836
#
#
# -------------------------------------------
#
#
# Query:  Who was called Scarface?
#
#  Score Model distilberta:  0.4459546047449112
# Time Model distilberta:  0.016863584518432617
#
#  Score Model mini_v3_12:  0.4381589126586914
# Time Model distilberta:  0.015456199645996094
#
#  Score Model mini_v3_6:  0.42807820677757263
# Time Model distilberta:  0.009772777557373047
#
#  Score Model roberta v3:  0.37392814725637435
# Time Model distilberta:  0.020581722259521484
#
#
# -------------------------------------------
#
#
# Query:  To which countries does the Himalayan mountain system extend?
#
#  Score Model distilberta:  0.4507235208153725
# Time Model distilberta:  0.0135650634765625
#
#  Score Model mini_v3_12:  0.42072314381599424
# Time Model distilberta:  0.015681028366088867
#
#  Score Model mini_v3_6:  0.40455006539821625
# Time Model distilberta:  0.009804010391235352
#
#  Score Model roberta v3:  0.3472393101453781
# Time Model distilberta:  0.020406723022460938
#
#
# -------------------------------------------
#
#
# Query:  Give me all books by William Goldman with more than 300 pages.
#
#  Score Model distilberta:  0.43896802425384523
# Time Model distilberta:  0.013608455657958984
#
#  Score Model mini_v3_12:  0.41500321686267855
# Time Model distilberta:  0.01708531379699707
#
#  Score Model mini_v3_6:  0.41200842320919034
# Time Model distilberta:  0.01298379898071289
#
#  Score Model roberta v3:  0.3183877047896385
# Time Model distilberta:  0.020843505859375
#
#
# -------------------------------------------
#
#
# Query:  Which books by Kerouac were published by Viking Press?
#
#  Score Model distilberta:  0.48121938526630403
# Time Model distilberta:  0.013371944427490234
#
#  Score Model mini_v3_12:  0.4422784298658371
# Time Model distilberta:  0.015267610549926758
#
#  Score Model mini_v3_6:  0.45156892865896225
# Time Model distilberta:  0.00973367691040039
#
#  Score Model roberta v3:  0.3847328615188599
# Time Model distilberta:  0.020551443099975586
#
#
# -------------------------------------------
#
#
# Query:  Give me a list of all American inventions.
#
#  Score Model distilberta:  0.3907842054963112
# Time Model distilberta:  0.013575315475463867
#
#  Score Model mini_v3_12:  0.47455993592739104
# Time Model distilberta:  0.01560211181640625
#
#  Score Model mini_v3_6:  0.340977236032486
# Time Model distilberta:  0.010041952133178711
#
#  Score Model roberta v3:  0.2870298971235752
# Time Model distilberta:  0.020038604736328125
#
#
# -------------------------------------------
#
#
# Query:  Who created the comic Captain America?
#
#  Score Model distilberta:  0.4342919200658798
# Time Model distilberta:  0.01459956169128418
#
#  Score Model mini_v3_12:  0.4451244813203812
# Time Model distilberta:  0.016184329986572266
#
#  Score Model mini_v3_6:  0.4600147485733032
# Time Model distilberta:  0.009674310684204102
#
#  Score Model roberta v3:  0.38618533551692963
# Time Model distilberta:  0.025262117385864258
#
#
# -------------------------------------------
#
#
# Query:  Which films starring Clint Eastwood did he direct himself?
#
#  Score Model distilberta:  0.44559634268283843
# Time Model distilberta:  0.014063835144042969
#
#  Score Model mini_v3_12:  0.4508342233300209
# Time Model distilberta:  0.015280961990356445
#
#  Score Model mini_v3_6:  0.4147302222251892
# Time Model distilberta:  0.010042667388916016
#
#  Score Model roberta v3:  0.38823505967855454
# Time Model distilberta:  0.02033543586730957
#
#
# -------------------------------------------
#
#
# Query:  In which city was the former Dutch queen Juliana buried?
#
#  Score Model distilberta:  0.46705624371767046
# Time Model distilberta:  0.013700246810913086
#
#  Score Model mini_v3_12:  0.4163616171479225
# Time Model distilberta:  0.023024320602416992
#
#  Score Model mini_v3_6:  0.4431400591135025
# Time Model distilberta:  0.010237455368041992
#
#  Score Model roberta v3:  0.369988272190094
# Time Model distilberta:  0.0202639102935791
#
#
# -------------------------------------------
#
#
# Query:  Give me a list of all trumpet players that were bandleaders.
#
#  Score Model distilberta:  0.4319476422667503
# Time Model distilberta:  0.013788700103759766
#
#  Score Model mini_v3_12:  0.4023811283707619
# Time Model distilberta:  0.017001628875732422
#
#  Score Model mini_v3_6:  0.39152449250221255
# Time Model distilberta:  0.015603065490722656
#
#  Score Model roberta v3:  0.37193593859672547
# Time Model distilberta:  0.022398710250854492
#
#
# -------------------------------------------
#
#
# Query:  Where is the residence of the prime minister of Spain?
#
#  Score Model distilberta:  0.48291507482528684
# Time Model distilberta:  0.01371908187866211
#
#  Score Model mini_v3_12:  0.4590546616911888
# Time Model distilberta:  0.016075849533081055
#
#  Score Model mini_v3_6:  0.482220331132412
# Time Model distilberta:  0.010842084884643555
#
#  Score Model roberta v3:  0.38014413982629774
# Time Model distilberta:  0.02988123893737793
#
#
# -------------------------------------------
#
#
# Query:  Which U.S. State has the abbreviation MN?
#
#  Score Model distilberta:  0.41695964604616165
# Time Model distilberta:  0.013392925262451172
#
#  Score Model mini_v3_12:  0.39838474661111833
# Time Model distilberta:  0.016304969787597656
#
#  Score Model mini_v3_6:  0.4241476231813431
# Time Model distilberta:  0.010065078735351562
#
#  Score Model roberta v3:  0.3414629656076431
# Time Model distilberta:  0.024821758270263672
#
#
# -------------------------------------------
#
#
# Query:  Show me all songs from Bruce Springsteen released between 1980 and 1990.
#
#  Score Model distilberta:  0.48336391627788544
# Time Model distilberta:  0.013659954071044922
#
#  Score Model mini_v3_12:  0.504983848631382
# Time Model distilberta:  0.016848087310791016
#
#  Score Model mini_v3_6:  0.5345655825734138
# Time Model distilberta:  0.010824203491210938
#
#  Score Model roberta v3:  0.3847458815574646
# Time Model distilberta:  0.020435810089111328
#
#
# -------------------------------------------
#
#
# Query:  Which movies did Sam Raimi direct after Army of Darkness?
#
#  Score Model distilberta:  0.4845187169313431
# Time Model distilberta:  0.013760089874267578
#
#  Score Model mini_v3_12:  0.46378342747688295
# Time Model distilberta:  0.015588521957397461
#
#  Score Model mini_v3_6:  0.4384435406327248
# Time Model distilberta:  0.010161399841308594
#
#  Score Model roberta v3:  0.3952848130464554
# Time Model distilberta:  0.019921541213989258
#
#
# -------------------------------------------
#
#
# Query:  Who wrote the lyrics for the Polish national anthem?
#
#  Score Model distilberta:  0.4974970239400864
# Time Model distilberta:  0.013484954833984375
#
#  Score Model mini_v3_12:  0.46642040997743606
# Time Model distilberta:  0.02217578887939453
#
#  Score Model mini_v3_6:  0.45447844117879865
# Time Model distilberta:  0.010203123092651367
#
#  Score Model roberta v3:  0.400484593808651
# Time Model distilberta:  0.020464420318603516
#
#
# -------------------------------------------
#
#
# Query:  Who painted The Storm on the Sea of Galilee?
#
#  Score Model distilberta:  0.45389089405536653
# Time Model distilberta:  0.013649940490722656
#
#  Score Model mini_v3_12:  0.4299791333079338
# Time Model distilberta:  0.01572728157043457
#
#  Score Model mini_v3_6:  0.4332035145163536
# Time Model distilberta:  0.009979486465454102
#
#  Score Model roberta v3:  0.3554781225323677
# Time Model distilberta:  0.02930307388305664
#
#
# -------------------------------------------
#
#
# Query:  Which country does the creator of Miffy come from?
#
#  Score Model distilberta:  0.44115347653627396
# Time Model distilberta:  0.013464689254760742
#
#  Score Model mini_v3_12:  0.39436582416296007
# Time Model distilberta:  0.017008543014526367
#
#  Score Model mini_v3_6:  0.4058351296186447
# Time Model distilberta:  0.010237693786621094
#
#  Score Model roberta v3:  0.4041835391521454
# Time Model distilberta:  0.022196054458618164
#
#
# -------------------------------------------
#
#
# Query:  For which label did Elvis record his first album?
#
#  Score Model distilberta:  0.4945289269089699
# Time Model distilberta:  0.013884305953979492
#
#  Score Model mini_v3_12:  0.5117067483067512
# Time Model distilberta:  0.016278505325317383
#
#  Score Model mini_v3_6:  0.49198698163032534
# Time Model distilberta:  0.010324478149414062
#
#  Score Model roberta v3:  0.3920520830154419
# Time Model distilberta:  0.020505666732788086
#
#
# -------------------------------------------
#
#
# Query:  Give me all female Russian astronauts.
#
#  Score Model distilberta:  0.4421523195505142
# Time Model distilberta:  0.01408696174621582
#
#  Score Model mini_v3_12:  0.38139827907085416
# Time Model distilberta:  0.015663623809814453
#
#  Score Model mini_v3_6:  0.39387368738651274
# Time Model distilberta:  0.009949207305908203
#
#  Score Model roberta v3:  0.33669385612010955
# Time Model distilberta:  0.02150130271911621
#
#
# -------------------------------------------
#
#
# Query:  In which country does the Nile start?
#
#  Score Model distilberta:  0.40867496937513353
# Time Model distilberta:  0.014958620071411133
#
#  Score Model mini_v3_12:  0.35111493527889254
# Time Model distilberta:  0.01619434356689453
#
#  Score Model mini_v3_6:  0.3404285976290703
# Time Model distilberta:  0.009793281555175781
#
#  Score Model roberta v3:  0.3227711224555969
# Time Model distilberta:  0.020246028900146484
#
#
# -------------------------------------------
#
#
# Query:  Which countries have places with more than two caves?
#
#  Score Model distilberta:  0.3316199904680252
# Time Model distilberta:  0.013971567153930664
#
#  Score Model mini_v3_12:  0.3703196847438812
# Time Model distilberta:  0.016468524932861328
#
#  Score Model mini_v3_6:  0.3844342198967934
# Time Model distilberta:  0.009981632232666016
#
#  Score Model roberta v3:  0.2778802815079689
# Time Model distilberta:  0.019975662231445312
#
#
# -------------------------------------------
#
#
# Query:  Which classis does the Millepede belong to?
#
#  Score Model distilberta:  0.5070504978299141
# Time Model distilberta:  0.013998746871948242
#
#  Score Model mini_v3_12:  0.3674131825566292
# Time Model distilberta:  0.016092300415039062
#
#  Score Model mini_v3_6:  0.3584554079174995
# Time Model distilberta:  0.009946346282958984
#
#  Score Model roberta v3:  0.39369722485542297
# Time Model distilberta:  0.029551267623901367
#
#
# -------------------------------------------
#
#
# Query:  Who created Goofy?
#
#  Score Model distilberta:  0.5013966220617294
# Time Model distilberta:  0.014162778854370117
#
#  Score Model mini_v3_12:  0.4648352584242821
# Time Model distilberta:  0.016100168228149414
#
#  Score Model mini_v3_6:  0.4489864096045494
# Time Model distilberta:  0.009778976440429688
#
#  Score Model roberta v3:  0.44409108519554136
# Time Model distilberta:  0.031885623931884766
#
#
# -------------------------------------------
#
#
# Query:  Give me the capitals of all countries in Africa.
#
#  Score Model distilberta:  0.40490756452083587
# Time Model distilberta:  0.01372075080871582
#
#  Score Model mini_v3_12:  0.3900064840912819
# Time Model distilberta:  0.016065120697021484
#
#  Score Model mini_v3_6:  0.362705160677433
# Time Model distilberta:  0.009959697723388672
#
#  Score Model roberta v3:  0.2935247176885605
# Time Model distilberta:  0.04537844657897949
#
#
# -------------------------------------------
#
#
# Query:  Give me all cities in New Jersey with more than 100000 inhabitants.
#
#  Score Model distilberta:  0.4039518955349922
# Time Model distilberta:  0.013982295989990234
#
#  Score Model mini_v3_12:  0.3814199829101563
# Time Model distilberta:  0.01720261573791504
#
#  Score Model mini_v3_6:  0.41652787327766416
# Time Model distilberta:  0.012922525405883789
#
#  Score Model roberta v3:  0.33953792572021485
# Time Model distilberta:  0.03204035758972168
#
#
# -------------------------------------------
#
#
# Query:  Which museum exhibits The Scream by Munch?
#
#  Score Model distilberta:  0.39806359499692917
# Time Model distilberta:  0.014319419860839844
#
#  Score Model mini_v3_12:  0.3759397229552269
# Time Model distilberta:  0.015563488006591797
#
#  Score Model mini_v3_6:  0.3948264843225479
# Time Model distilberta:  0.009864568710327148
#
#  Score Model roberta v3:  0.35513789802789686
# Time Model distilberta:  0.0344851016998291
#
#
# -------------------------------------------
#
#
# Query:  Which states border Illinois?
#
#  Score Model distilberta:  0.45091723680496215
# Time Model distilberta:  0.01392984390258789
#
#  Score Model mini_v3_12:  0.38904170572757724
# Time Model distilberta:  0.015436410903930664
#
#  Score Model mini_v3_6:  0.38531505048274994
# Time Model distilberta:  0.009583711624145508
#
#  Score Model roberta v3:  0.3218276298046112
# Time Model distilberta:  0.049462318420410156
#
#
# -------------------------------------------
#
#
# Query:  Which mountain is the highest after the Annapurna?
#
#  Score Model distilberta:  0.5185043802857399
# Time Model distilberta:  0.013478279113769531
#
#  Score Model mini_v3_12:  0.4877724653482437
# Time Model distilberta:  0.01593160629272461
#
#  Score Model mini_v3_6:  0.45675238221883774
# Time Model distilberta:  0.00993490219116211
#
#  Score Model roberta v3:  0.3751049965620041
# Time Model distilberta:  0.03928852081298828
#
#
# -------------------------------------------
#
#
# Query:  In which films directed by Garry Marshall was Julia Roberts starring?
#
#  Score Model distilberta:  0.47068013101816175
# Time Model distilberta:  0.0134735107421875
#
#  Score Model mini_v3_12:  0.4684164476394653
# Time Model distilberta:  0.015676021575927734
#
#  Score Model mini_v3_6:  0.4665914049744606
# Time Model distilberta:  0.009887933731079102
#
#  Score Model roberta v3:  0.41109818071126936
# Time Model distilberta:  0.03766465187072754
#
#
# -------------------------------------------
#
#
# Query:  Which bridges are of the same type as the Manhattan Bridge?
#
#  Score Model distilberta:  0.4717483526468277
# Time Model distilberta:  0.013801813125610352
#
#  Score Model mini_v3_12:  0.46474783718585966
# Time Model distilberta:  0.01566624641418457
#
#  Score Model mini_v3_6:  0.4830235505104065
# Time Model distilberta:  0.01205754280090332
#
#  Score Model roberta v3:  0.4127687245607376
# Time Model distilberta:  0.032570600509643555
#
#
# -------------------------------------------
#
#
# Query:  Which European countries have a constitutional monarchy?
#
#  Score Model distilberta:  0.45970269054174423
# Time Model distilberta:  0.01455545425415039
#
#  Score Model mini_v3_12:  0.4238546270132065
# Time Model distilberta:  0.01854562759399414
#
#  Score Model mini_v3_6:  0.4111066609621048
# Time Model distilberta:  0.009670495986938477
#
#  Score Model roberta v3:  0.3239788025617599
# Time Model distilberta:  0.030521392822265625
#
#
# -------------------------------------------
#
#
# Query:  Which awards did WikiLeaks win?
#
#  Score Model distilberta:  0.46266627103090285
# Time Model distilberta:  0.01372838020324707
#
#  Score Model mini_v3_12:  0.41751718282699585
# Time Model distilberta:  0.016049861907958984
#
#  Score Model mini_v3_6:  0.4465818440914154
# Time Model distilberta:  0.009867429733276367
#
#  Score Model roberta v3:  0.3277480068802834
# Time Model distilberta:  0.030076026916503906
#
#
# -------------------------------------------
#
#
# Query:  Who is the daughter of Bill Clinton married to?
#
#  Score Model distilberta:  0.42097007781267165
# Time Model distilberta:  0.014089584350585938
#
#  Score Model mini_v3_12:  0.3906419879198074
# Time Model distilberta:  0.016604900360107422
#
#  Score Model mini_v3_6:  0.4136738386750221
# Time Model distilberta:  0.009713411331176758
#
#  Score Model roberta v3:  0.31851311683654787
# Time Model distilberta:  0.04265022277832031
#
#
# -------------------------------------------
#
#
# Query:  Which state of the USA has the highest population density?
#
#  Score Model distilberta:  0.3609942311048508
# Time Model distilberta:  0.013857364654541016
#
#  Score Model mini_v3_12:  0.3200066351890564
# Time Model distilberta:  0.0166170597076416
#
#  Score Model mini_v3_6:  0.3090601879358292
# Time Model distilberta:  0.009743213653564453
#
#  Score Model roberta v3:  0.2325243929028511
# Time Model distilberta:  0.02959918975830078
#
#
# -------------------------------------------
#
#
# Query:  What is the currency of the Czech Republic?
#
#  Score Model distilberta:  0.43204997062683104
# Time Model distilberta:  0.013615608215332031
#
#  Score Model mini_v3_12:  0.42670328736305235
# Time Model distilberta:  0.0157320499420166
#
#  Score Model mini_v3_6:  0.3961612451076508
# Time Model distilberta:  0.009828567504882812
#
#  Score Model roberta v3:  0.3552960500121117
# Time Model distilberta:  0.03382539749145508
#
#
# -------------------------------------------
#
#
# Query:  Which countries in the European Union adopted the Euro?
#
#  Score Model distilberta:  0.46881052404642104
# Time Model distilberta:  0.01354074478149414
#
#  Score Model mini_v3_12:  0.4678009468317032
# Time Model distilberta:  0.01569986343383789
#
#  Score Model mini_v3_6:  0.4789657729864121
# Time Model distilberta:  0.00966954231262207
#
#  Score Model roberta v3:  0.3717781952023506
# Time Model distilberta:  0.05286431312561035
#
#
# -------------------------------------------
#
#
# Query:  Which countries have more than two official languages?
#
#  Score Model distilberta:  0.41160134971141815
# Time Model distilberta:  0.020170211791992188
#
#  Score Model mini_v3_12:  0.40575595557689664
# Time Model distilberta:  0.015177726745605469
#
#  Score Model mini_v3_6:  0.41308690011501314
# Time Model distilberta:  0.010287761688232422
#
#  Score Model roberta v3:  0.3163922671973705
# Time Model distilberta:  0.037652015686035156
#
#
# -------------------------------------------
#
#
# Query:  Who is the owner of Universal Studios?
#
#  Score Model distilberta:  0.42970232874155045
# Time Model distilberta:  0.013743162155151367
#
#  Score Model mini_v3_12:  0.4197686517238617
# Time Model distilberta:  0.01563549041748047
#
#  Score Model mini_v3_6:  0.41251018196344375
# Time Model distilberta:  0.009796380996704102
#
#  Score Model roberta v3:  0.36826657861471174
# Time Model distilberta:  0.03507828712463379
#
#
# -------------------------------------------
#
#
# Query:  Through which countries does the Yenisei river flow?
#
#  Score Model distilberta:  0.4819374552369118
# Time Model distilberta:  0.013924121856689453
#
#  Score Model mini_v3_12:  0.40383988559246065
# Time Model distilberta:  0.017815589904785156
#
#  Score Model mini_v3_6:  0.4321742308139801
# Time Model distilberta:  0.009981155395507812
#
#  Score Model roberta v3:  0.3918737265467644
# Time Model distilberta:  0.020940542221069336
#
#
# -------------------------------------------
#
#
# Query:  Which monarchs of the United Kingdom were married to a German?
#
#  Score Model distilberta:  0.4688007140159607
# Time Model distilberta:  0.014229297637939453
#
#  Score Model mini_v3_12:  0.4406970939040184
# Time Model distilberta:  0.01575779914855957
#
#  Score Model mini_v3_6:  0.4004201027750969
# Time Model distilberta:  0.009867191314697266
#
#  Score Model roberta v3:  0.4205775639414787
# Time Model distilberta:  0.020937681198120117
#
#
# -------------------------------------------
#
#
# Query:  Which river does the Brooklyn Bridge cross?
#
#  Score Model distilberta:  0.5624565160274506
# Time Model distilberta:  0.013777017593383789
#
#  Score Model mini_v3_12:  0.5372878292202949
# Time Model distilberta:  0.015552282333374023
#
#  Score Model mini_v3_6:  0.5522076338529587
# Time Model distilberta:  0.010056257247924805
#
#  Score Model roberta v3:  0.4826325243711472
# Time Model distilberta:  0.02167963981628418
#
#
# -------------------------------------------
#
#
# Query:  What is the highest mountain in Australia?
#
#  Score Model distilberta:  0.5173728480935097
# Time Model distilberta:  0.013330698013305664
#
#  Score Model mini_v3_12:  0.5058827900886536
# Time Model distilberta:  0.015623092651367188
#
#  Score Model mini_v3_6:  0.49309041529893877
# Time Model distilberta:  0.009926319122314453
#
#  Score Model roberta v3:  0.45802979677915573
# Time Model distilberta:  0.02102518081665039
#
#
# -------------------------------------------
#
#
# Query:  Give me all soccer clubs in Spain.
#
#  Score Model distilberta:  0.6140852552652359
# Time Model distilberta:  0.013945579528808594
#
#  Score Model mini_v3_12:  0.49639056891202926
# Time Model distilberta:  0.015583276748657227
#
#  Score Model mini_v3_6:  0.5431728529930114
# Time Model distilberta:  0.010177850723266602
#
#  Score Model roberta v3:  0.4612422287464142
# Time Model distilberta:  0.020531892776489258
#
#
# -------------------------------------------
#
#
# Query:  What are the official languages of the Philippines?
#
#  Score Model distilberta:  0.5491888076066971
# Time Model distilberta:  0.013780593872070312
#
#  Score Model mini_v3_12:  0.5041145715117454
# Time Model distilberta:  0.015409708023071289
#
#  Score Model mini_v3_6:  0.4945155653357506
# Time Model distilberta:  0.00969552993774414
#
#  Score Model roberta v3:  0.4679951572418213
# Time Model distilberta:  0.019745349884033203
#
#
# -------------------------------------------
#
#
# Query:  Who is the mayor of New York City?
#
#  Score Model distilberta:  0.5231599551439285
# Time Model distilberta:  0.013470888137817383
#
#  Score Model mini_v3_12:  0.5297715404629707
# Time Model distilberta:  0.015798330307006836
#
#  Score Model mini_v3_6:  0.541633662879467
# Time Model distilberta:  0.010343074798583984
#
#  Score Model roberta v3:  0.4656949830055237
# Time Model distilberta:  0.020664691925048828
#
#
# -------------------------------------------
#
#
# Query:  Which telecommunications organizations are located in Belgium?
#
#  Score Model distilberta:  0.454267343878746
# Time Model distilberta:  0.014226913452148438
#
#  Score Model mini_v3_12:  0.4295262423157692
# Time Model distilberta:  0.015381574630737305
#
#  Score Model mini_v3_6:  0.43768230676651
# Time Model distilberta:  0.01028895378112793
#
#  Score Model roberta v3:  0.4068742433190346
# Time Model distilberta:  0.020025014877319336
#
#
# -------------------------------------------
#
#
# Query:  What is the highest place of Karakoram?
#
#  Score Model distilberta:  0.5827813816070556
# Time Model distilberta:  0.013880491256713867
#
#  Score Model mini_v3_12:  0.4727781665325165
# Time Model distilberta:  0.015495538711547852
#
#  Score Model mini_v3_6:  0.4382678294181824
# Time Model distilberta:  0.010150432586669922
#
#  Score Model roberta v3:  0.4523304784297943
# Time Model distilberta:  0.020506620407104492
#
#
# -------------------------------------------
#
#
# ...
# Time Model distilberta:  0.015526533126831055
#
#  Score Model mini_v3_6:  0.5269266292452812
# Time Model distilberta:  0.010142326354980469
#
#  Score Model roberta v3:  0.3799611833691597
# Time Model distilberta:  0.019823074340820312
#
#
# -------------------------------------------
#
#
# Query:  ratt albums
#
#  Score Model distilberta:  0.5108645689487458
# Time Model distilberta:  0.013289451599121094
#
#  Score Model mini_v3_12:  0.4749613729119301
# Time Model distilberta:  0.01530313491821289
#
#  Score Model mini_v3_6:  0.44545023709535597
# Time Model distilberta:  0.01034092903137207
#
#  Score Model roberta v3:  0.4252416968345642
# Time Model distilberta:  0.019128799438476562
#
#
# -------------------------------------------
#
#
# Query:  republics of the former Yugoslavia
#
#  Score Model distilberta:  0.546469055712223
# Time Model distilberta:  0.013650655746459961
#
#  Score Model mini_v3_12:  0.45043280243873596
# Time Model distilberta:  0.01535487174987793
#
#  Score Model mini_v3_6:  0.4370002689957619
# Time Model distilberta:  0.010006189346313477
#
#  Score Model roberta v3:  0.43869744569063185
# Time Model distilberta:  0.020293712615966797
#
#
# -------------------------------------------
#
#
# Query:  revolutionaries of 1959 in Cuba
#
#  Score Model distilberta:  0.4926639372110367
# Time Model distilberta:  0.013862133026123047
#
#  Score Model mini_v3_12:  0.465775243639946
# Time Model distilberta:  0.015087366104125977
#
#  Score Model mini_v3_6:  0.48808005690574646
# Time Model distilberta:  0.010238170623779297
#
#  Score Model roberta v3:  0.4092233645915985
# Time Model distilberta:  0.02101612091064453
#
#
# -------------------------------------------
#
#
# Query:  standard axioms of set theory
#
#  Score Model distilberta:  0.42988119810819625
# Time Model distilberta:  0.013872861862182617
#
#  Score Model mini_v3_12:  0.39131945312023164
# Time Model distilberta:  0.015533685684204102
#
#  Score Model mini_v3_6:  0.4172899001836777
# Time Model distilberta:  0.01072549819946289
#
#  Score Model roberta v3:  0.31938200041651726
# Time Model distilberta:  0.0211029052734375
#
#
# -------------------------------------------
#
#
# Query:  states that border oklahoma
#
#  Score Model distilberta:  0.39225215554237364
# Time Model distilberta:  0.014052152633666992
#
#  Score Model mini_v3_12:  0.4250440573692322
# Time Model distilberta:  0.015174388885498047
#
#  Score Model mini_v3_6:  0.4116451272368431
# Time Model distilberta:  0.00967860221862793
#
#  Score Model roberta v3:  0.31529791712760924
# Time Model distilberta:  0.021677255630493164
#
#
# -------------------------------------------
#
#
# Query:  ten ancient Greek city-kingdoms of Cyprus
#
#  Score Model distilberta:  0.5535695025324822
# Time Model distilberta:  0.013470649719238281
#
#  Score Model mini_v3_12:  0.45217646718025206
# Time Model distilberta:  0.016926050186157227
#
#  Score Model mini_v3_6:  0.46043688386678694
# Time Model distilberta:  0.009904623031616211
#
#  Score Model roberta v3:  0.3865770474076271
# Time Model distilberta:  0.02033710479736328
#
#
# -------------------------------------------
#
#
# Query:  Axis powers of World War II
#
#  Score Model distilberta:  0.4140592610836029
# Time Model distilberta:  0.013718128204345703
#
#  Score Model mini_v3_12:  0.4304835596680641
# Time Model distilberta:  0.015491008758544922
#
#  Score Model mini_v3_6:  0.4154888692498207
# Time Model distilberta:  0.010243415832519531
#
#  Score Model roberta v3:  0.35326759904623034
# Time Model distilberta:  0.021873950958251953
#
#
# -------------------------------------------
#
#
# Query:  the four of the companions of the prophet
#
#  Score Model distilberta:  0.39212180793285367
# Time Model distilberta:  0.01370096206665039
#
#  Score Model mini_v3_12:  0.3616467145085335
# Time Model distilberta:  0.016035795211791992
#
#  Score Model mini_v3_6:  0.34868491023778914
# Time Model distilberta:  0.010146379470825195
#
#  Score Model roberta v3:  0.3047307062149048
# Time Model distilberta:  0.022794246673583984
#
#
# -------------------------------------------
#
#
# Query:  twelve tribes or sons of Israel
#
#  Score Model distilberta:  0.49163459181785585
# Time Model distilberta:  0.013431787490844727
#
#  Score Model mini_v3_12:  0.4133519846200943
# Time Model distilberta:  0.016233444213867188
#
#  Score Model mini_v3_6:  0.41286412090063096
# Time Model distilberta:  0.010087251663208008
#
#  Score Model roberta v3:  0.33648781806230543
# Time Model distilberta:  0.020476579666137695
#
#
# -------------------------------------------
#
#
# Query:  what books did paul of tarsus write?
#
#  Score Model distilberta:  0.48827644020318983
# Time Model distilberta:  0.013903379440307617
#
#  Score Model mini_v3_12:  0.4556062236428261
# Time Model distilberta:  0.015909910202026367
#
#  Score Model mini_v3_6:  0.45838471859693525
# Time Model distilberta:  0.009646415710449219
#
#  Score Model roberta v3:  0.3799695175886154
# Time Model distilberta:  0.02373361587524414
#
#
# -------------------------------------------
#
#
# Query:  what languages do they speak in afghanistan
#
#  Score Model distilberta:  0.5222786167263984
# Time Model distilberta:  0.013819217681884766
#
#  Score Model mini_v3_12:  0.4385996851325035
# Time Model distilberta:  0.015424251556396484
#
#  Score Model mini_v3_6:  0.4196401131153107
# Time Model distilberta:  0.010154008865356445
#
#  Score Model roberta v3:  0.43188821196556093
# Time Model distilberta:  0.02711939811706543
#
#
# -------------------------------------------
#
#
# Query:  where the British monarch is also head of state
#
#  Score Model distilberta:  0.46551045298576355
# Time Model distilberta:  0.013666868209838867
#
#  Score Model mini_v3_12:  0.4439158883690834
# Time Model distilberta:  0.015356779098510742
#
#  Score Model mini_v3_6:  0.45276814192533493
# Time Model distilberta:  0.009531736373901367
#
#  Score Model roberta v3:  0.34733299285173413
# Time Model distilberta:  0.021161556243896484
#
#
# -------------------------------------------
#
#
# Query:  who invented the python programming language
#
#  Score Model distilberta:  0.4415102589130402
# Time Model distilberta:  0.014077901840209961
#
#  Score Model mini_v3_12:  0.43454754024744036
# Time Model distilberta:  0.015493631362915039
#
#  Score Model mini_v3_6:  0.4292805966734886
# Time Model distilberta:  0.00988316535949707
#
#  Score Model roberta v3:  0.36958731949329376
# Time Model distilberta:  0.021724224090576172
#
#
# -------------------------------------------
#
#
# Query:  wonders of the ancient world
#
#  Score Model distilberta:  0.40388796776533126
# Time Model distilberta:  0.014287948608398438
#
#  Score Model mini_v3_12:  0.38710300892591476
# Time Model distilberta:  0.015108108520507812
#
#  Score Model mini_v3_6:  0.4058696386218071
# Time Model distilberta:  0.009791374206542969
#
#  Score Model roberta v3:  0.3206823420524597
# Time Model distilberta:  0.020816564559936523
#
#
# -------------------------------------------
#
#
# Query:  boroughs of New York City
#
#  Score Model distilberta:  0.44236830323934556
# Time Model distilberta:  0.013766765594482422
#
#  Score Model mini_v3_12:  0.4652180531620979
# Time Model distilberta:  0.021329402923583984
#
#  Score Model mini_v3_6:  0.5001506841182709
# Time Model distilberta:  0.009625911712646484
#
#  Score Model roberta v3:  0.3956326451897621
# Time Model distilberta:  0.024208545684814453
#
#
# -------------------------------------------
#
#
# Query:  Branches of the US military
#
#  Score Model distilberta:  0.4350987783074379
# Time Model distilberta:  0.013614416122436523
#
#  Score Model mini_v3_12:  0.45753358632326124
# Time Model distilberta:  0.016767501831054688
#
#  Score Model mini_v3_6:  0.4648127743601799
# Time Model distilberta:  0.009986639022827148
#
#  Score Model roberta v3:  0.3699604591727257
# Time Model distilberta:  0.021128177642822266
#
#
# -------------------------------------------
#
#
# Query:  continents in the world
#
#  Score Model distilberta:  0.30607425928115845
# Time Model distilberta:  0.014365911483764648
#
#  Score Model mini_v3_12:  0.41049615502357484
# Time Model distilberta:  0.015613794326782227
#
#  Score Model mini_v3_6:  0.4185222461819649
# Time Model distilberta:  0.011557579040527344
#
#  Score Model roberta v3:  0.27407639056444166
# Time Model distilberta:  0.02097630500793457
#
#
# -------------------------------------------
#
#
# Query:  degrees of Eastern Orthodox monasticism
#
#  Score Model distilberta:  0.4344244825839996
# Time Model distilberta:  0.013734817504882812
#
#  Score Model mini_v3_12:  0.4118710282444954
# Time Model distilberta:  0.015635013580322266
#
#  Score Model mini_v3_6:  0.4090343940258026
# Time Model distilberta:  0.009539604187011719
#
#  Score Model roberta v3:  0.3758899906277657
# Time Model distilberta:  0.020581722259521484
#
#
# -------------------------------------------
#
#
# Query:  Carriers that Blackberry makes phones for.
#
#  Score Model distilberta:  0.33374143570661546
# Time Model distilberta:  0.014075994491577148
#
#  Score Model mini_v3_12:  0.3862276592850685
# Time Model distilberta:  0.015249252319335938
#
#  Score Model mini_v3_6:  0.3900895223021507
# Time Model distilberta:  0.009970903396606445
#
#  Score Model roberta v3:  0.3005075904726982
# Time Model distilberta:  0.020341873168945312
#
#
# -------------------------------------------
#
#
# Query:  Campuses of Indiana University.
#
#  Score Model distilberta:  0.4422832030057907
# Time Model distilberta:  0.013605117797851562
#
#  Score Model mini_v3_12:  0.4829260519146919
# Time Model distilberta:  0.015070676803588867
#
#  Score Model mini_v3_6:  0.4872598150372505
# Time Model distilberta:  0.009516477584838867
#
#  Score Model roberta v3:  0.44870712161064147
# Time Model distilberta:  0.020555973052978516
#
#
# -------------------------------------------
#
#
# Query:  Donors to the Home Depot Foundation.
#
#  Score Model distilberta:  0.33315034240484237
# Time Model distilberta:  0.013876914978027344
#
#  Score Model mini_v3_12:  0.3594737410545349
# Time Model distilberta:  0.01540684700012207
#
#  Score Model mini_v3_6:  0.34216583460569383
# Time Model distilberta:  0.009993553161621094
#
#  Score Model roberta v3:  0.27514973729848863
# Time Model distilberta:  0.02088141441345215
#
#
# -------------------------------------------
#
#
# Query:  Airlines that Air Canada has code share flights with.
#
#  Score Model distilberta:  0.4384156334400177
# Time Model distilberta:  0.013759851455688477
#
#  Score Model mini_v3_12:  0.4060635307431221
# Time Model distilberta:  0.01566147804260254
#
#  Score Model mini_v3_6:  0.3786914423108101
# Time Model distilberta:  0.00974273681640625
#
#  Score Model roberta v3:  0.35452130556106565
# Time Model distilberta:  0.021030902862548828
#
#
# -------------------------------------------
#
#
# Query:  Authors awarded an Anthony Award at Bouchercon in 2007.
#
#  Score Model distilberta:  0.48757304102182386
# Time Model distilberta:  0.013638019561767578
#
#  Score Model mini_v3_12:  0.46466759592294693
# Time Model distilberta:  0.015631675720214844
#
#  Score Model mini_v3_6:  0.4448742809891701
# Time Model distilberta:  0.014298200607299805
#
#  Score Model roberta v3:  0.40588045090436936
# Time Model distilberta:  0.020828962326049805
#
#
# -------------------------------------------
#
#
# Query:  Universities that are members of the SEC conference for football.
#
#  Score Model distilberta:  0.48629095405340195
# Time Model distilberta:  0.014288187026977539
#
#  Score Model mini_v3_12:  0.4839890766143799
# Time Model distilberta:  0.01624321937561035
#
#  Score Model mini_v3_6:  0.4928017535805702
# Time Model distilberta:  0.011196613311767578
#
#  Score Model roberta v3:  0.39992842704057696
# Time Model distilberta:  0.020699024200439453
#
#
# -------------------------------------------
#
#
# Query:  Sponsors of the Mancuso quilt festivals.
#
#  Score Model distilberta:  0.36718818575143813
# Time Model distilberta:  0.013652563095092773
#
#  Score Model mini_v3_12:  0.35911844730377196
# Time Model distilberta:  0.016084671020507812
#
#  Score Model mini_v3_6:  0.37736408472061156
# Time Model distilberta:  0.010042905807495117
#
#  Score Model roberta v3:  0.296987684071064
# Time Model distilberta:  0.020733356475830078
#
#
# -------------------------------------------
#
#
# Query:  Members of the band Jefferson Airplane.
#
#  Score Model distilberta:  0.5042925250530242
# Time Model distilberta:  0.013628959655761719
#
#  Score Model mini_v3_12:  0.4322103741765022
# Time Model distilberta:  0.024035215377807617
#
#  Score Model mini_v3_6:  0.45536465048789976
# Time Model distilberta:  0.010115623474121094
#
#  Score Model roberta v3:  0.44262884885072706
# Time Model distilberta:  0.020713329315185547
#
#
# -------------------------------------------
#
#
# Query:  Companies that John Hennessey serves on the board of.
#
#  Score Model distilberta:  0.4406538477540016
# Time Model distilberta:  0.013699531555175781
#
#  Score Model mini_v3_12:  0.4107064601778984
# Time Model distilberta:  0.016745805740356445
#
#  Score Model mini_v3_6:  0.4001390478014946
# Time Model distilberta:  0.010224342346191406
#
#  Score Model roberta v3:  0.40200038462877274
# Time Model distilberta:  0.02099752426147461
#
#
# -------------------------------------------
#
#
# Query:  Winners of the ACM Athena award.
#
#  Score Model distilberta:  0.4938424402475357
# Time Model distilberta:  0.013700246810913086
#
#  Score Model mini_v3_12:  0.40667999148368833
# Time Model distilberta:  0.017139434814453125
#
#  Score Model mini_v3_6:  0.4325238260626793
# Time Model distilberta:  0.009946823120117188
#
#  Score Model roberta v3:  0.3681296530365944
# Time Model distilberta:  0.021116018295288086
#
#
# -------------------------------------------
#
#
# Query:  Scotch whisky distilleries on the island of Islay.
#
#  Score Model distilberta:  0.5099760168790817
# Time Model distilberta:  0.015153884887695312
#
#  Score Model mini_v3_12:  0.4173028266429901
# Time Model distilberta:  0.017904043197631836
#
#  Score Model mini_v3_6:  0.4083124861121178
# Time Model distilberta:  0.010823965072631836
#
#  Score Model roberta v3:  0.4039609631896019
# Time Model distilberta:  0.02062225341796875
#
#
# -------------------------------------------
#
#
# Query:  Professional sports teams in Philadelphia.
#
#  Score Model distilberta:  0.5177457672357559
# Time Model distilberta:  0.019167661666870117
#
#  Score Model mini_v3_12:  0.4610759609937668
# Time Model distilberta:  0.016895294189453125
#
#  Score Model mini_v3_6:  0.46238213539123535
# Time Model distilberta:  0.00986790657043457
#
#  Score Model roberta v3:  0.4480812785029411
# Time Model distilberta:  0.02048039436340332
#
#
# -------------------------------------------
#
#
# Query:  Products of Medimmune, Inc.
#
#  Score Model distilberta:  0.3680863502621651
# Time Model distilberta:  0.015063285827636719
#
#  Score Model mini_v3_12:  0.32005149096250535
# Time Model distilberta:  0.019125699996948242
#
#  Score Model mini_v3_6:  0.3139654067158699
# Time Model distilberta:  0.00993967056274414
#
#  Score Model roberta v3:  0.31206622123718264
# Time Model distilberta:  0.020488500595092773
#
#
# -------------------------------------------
#
#
# Query:  Organizations that award Nobel prizes.
#
#  Score Model distilberta:  0.4670906588435173
# Time Model distilberta:  0.01436758041381836
#
#  Score Model mini_v3_12:  0.45319060653448107
# Time Model distilberta:  0.015537261962890625
#
#  Score Model mini_v3_6:  0.46496251344680783
# Time Model distilberta:  0.010009050369262695
#
#  Score Model roberta v3:  0.428438296020031
# Time Model distilberta:  0.020430803298950195
#
#
# -------------------------------------------
#
#
# Query:  Airlines that currently use Boeing 747 planes.
#
#  Score Model distilberta:  0.47032156139612197
# Time Model distilberta:  0.014141082763671875
#
#  Score Model mini_v3_12:  0.44782799899578096
# Time Model distilberta:  0.01653265953063965
#
#  Score Model mini_v3_6:  0.46169899821281435
# Time Model distilberta:  0.009759187698364258
#
#  Score Model roberta v3:  0.36834642946720125
# Time Model distilberta:  0.02050304412841797
#
#
# -------------------------------------------
#
#
# Query:  Members of The Beaux Arts Trio.
#
#  Score Model distilberta:  0.44818689197301864
# Time Model distilberta:  0.013834714889526367
#
#  Score Model mini_v3_12:  0.366677106320858
# Time Model distilberta:  0.015771865844726562
#
#  Score Model mini_v3_6:  0.3964193207025528
# Time Model distilberta:  0.011916875839233398
#
#  Score Model roberta v3:  0.3197458428144455
# Time Model distilberta:  0.019960403442382812

# %% [markdown]
# After testing our models, we figure out that the first one is the best. It is the most cost-effictive between speed and efficiency.

# %% [markdown]
# ##**Approximate nearest neighbours**

# %%
def ANN_faiss(corpus_emb,model,emb_size,cluster,probe,Scores):
  """ 
    Use the faiss approach to speed up the algorithms

    Parameters
    ----------
    model: <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
    corpus_emb: <class 'torch.Tensor'>
    emb_size: int
    cluster: int
    probe: int
    Scores: list

  """

  embedding_size = emb_size    #Size of embeddings
  top_k_hits = 100        #Output k hits
  n_clusters = cluster

  quantizer = faiss.IndexFlatIP(embedding_size)
  index = faiss.IndexIVFFlat(quantizer, embedding_size, 
                             n_clusters, faiss.METRIC_INNER_PRODUCT)
  index.nprobe = probe

  #print("Start creating FAISS index")
  # First, we need to normalize vectors to unit length
  corpus_embeddings = corpus_emb.cpu()
  corpus_embeddings = corpus_embeddings / np.linalg.norm(corpus_embeddings, axis=1)[:, None]
  # Then we train the index to find a suitable clustering
  index.train(corpus_embeddings)
  # Finally we add all embeddings to the index
  index.add(corpus_embeddings)

  for query in queries_val:
    start_time = time.time()
    question_embedding = model.encode(query)
    #FAISS works with inner product (dot product). When we normalize vectors to unit length, inner product is equal to cosine similarity
    question_embedding = question_embedding / np.linalg.norm(question_embedding)
    question_embedding = np.expand_dims(question_embedding, axis=0)
    # Search in FAISS. It returns a matrix with distances and corpus ids.
    distances, corpus_ids = index.search(question_embedding, top_k_hits)
    # We extract corpus ids and scores for the first query
    hits = [{'corpus_id': id, 'score': score} for id, score in zip(corpus_ids[0], distances[0])]
    hits = sorted(hits, key=lambda x: x['score'], reverse=True)
    end_time = time.time()
    #print("\nInput question:", query)
    #print("\nResults (after {:.3f} seconds):".format(end_time-start_time))
    L_score = [d['score'] for d in hits]
    result = sum(L_score)/top_k_hits
    #print("Score: ",result)
    Scores.append(result)

# %% [markdown]
# Next we want to change differents parameters to see if we can get a good combination:
# - First we will change the number of clusters
# - Sexond we will change the number of neighbors

# %%
Clusters = [128,256,512,1024,2048]
for cluster in Clusters:
  Scores = []
  ANN_faiss(List_model[0],L_model[0],768,cluster,10,Scores)
  print("\n------------------------------------\n")
  print("Nb de cluster: ",cluster)
  print("Score: ",sum(Scores)/len(Scores))
# Out:
# ------------------------------------
#
# Nb de cluster:  128
# Score:  0.44146069394759807
#
# ------------------------------------
#
# Nb de cluster:  256
# Score:  0.4390012654125689
#
# ------------------------------------
#
# Nb de cluster:  512
# Score:  0.43631949677914383
#
# ------------------------------------
#
# Nb de cluster:  1024
# Score:  0.43246338729113376
#
# ------------------------------------
#
# Nb de cluster:  2048
# Score:  0.42738040986880654

# %%
probe = [5,10,15,20]
for p in probe:
  Scores = []
  ANN_faiss(List_model[0],L_model[0],768,1024,p,Scores)
  print("\n------------------------------------\n")
  print("Nb de Neigbourgh: ",probe)
  print("Score: ",sum(Scores)/len(Scores))
# Out:
# ------------------------------------
#
# Nb de Neigbourgh:  [5, 10, 15, 20]
# Score:  0.42030490662008496
#
# ------------------------------------
#
# Nb de Neigbourgh:  [5, 10, 15, 20]
# Score:  0.43246338729113376
#
# ------------------------------------
#
# Nb de Neigbourgh:  [5, 10, 15, 20]
# Score:  0.43757598299831174
#
# ------------------------------------
#
# Nb de Neigbourgh:  [5, 10, 15, 20]
# Score:  0.44026761355362837

# %% [markdown]
# We can observed that the model is more efficient with low cluster but also more efficient with high probe.
